# %% [markdown]
# # Travellog
# An old personal Travellog Spanning from 2018 to 2020. Original data Stored on OneDrive

# %%
import pandas as pd

# Load the XLSX file
df = pd.read_excel('data/Reiseprotokoll.xlsx')

# %%
# Print bar chart of the distance travelled with a Verkehrsmittel
df.groupby('Verkehrsmittel')['Kilometer'].sum().plot.bar()
# Out:
# <Axes: xlabel='Verkehrsmittel'>

# %%
# Print bar chart of the Start and Ziel of the Reise
# make the chart wider
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 5]

#df.groupby(['Start', 'Ziel'])['Kilometer'].sum().plot.bar()
